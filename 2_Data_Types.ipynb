# %% [markdown]
# # 2. Data Types

# %% [markdown]
# # Data Types
# Python supports various data types, including integers, floats, strings, lists, tuples, dictionaries, and more.
#
# A. Numeric -
# 1. Integers - Whole numbers without decimals.
# 2. Floats - Numbers with decimals.
# 3. Complex - Numbers with both real and imaginary parts.
#
# B. Dictionary
#
# C. Boolean
#
# D. Set
#
# E. Sequence / Collection Type -
# 1. Strings - Text enclosed in single or double quotes.
# 2. Lists - Ordered collections of items.
# 3. Tuples - Immutable collections of items.

# %% [markdown]
# # Rules for Python variables
# 1. A Python variable name must start with a letter or the underscore character.
# 2. A Python variable name cannot start with a number.
# 3. A Python variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ ).
# 4. Variable in Python names are case-sensitive (name, Name, and NAME are three different variables).
# 5. The reserved words(keywords) in Python cannot be used to name the variable in Python.

# %%
'''
How to define variable ?

'''

variable1 = 12154     # correct way
_variable1 = 12154    # correct way

1variable = 12154     # wrong way
$variable = 12154     # wrong way
variable* = 12154     # wrong way
variable$ = 12154     # wrong way
# Out:
#   File "<ipython-input-28-27216045d063>", line 9
#     1variable = 12154     # wrong way
#     ^
# SyntaxError: invalid decimal literal

# %%
# Here are the 3 examples. Which options are correct ?

'''

1. Example

print = 7
print(print)

2. Example

PRINT = 7
print(PRINT)

3. Example

Data-Squad = 7
print(Data-Squad)

'''

# %% [markdown]
# # Type Casting in Python (Implicit and Explicit)
#
# Type Casting is the method to convert the Python variable datatype into a certain data type in order to perform the required operation by users.
#
# # There can be two types of Type Casting in Python -
#
# 1. Python Implicit Type Conversion
# 2. Python Explicit Type Conversion

# %% [markdown]
# # 1. Implicit Type Conversion in Python -
# In this, method, Python converts the datatype into another datatype automatically. Users don’t have to involve in this process.

# %%
Vrushabh = input()
print(type(Vrushabh))
# Out:
# 10
# <class 'str'>

# %%
Data = input()
print(type(Data))
# Out:
# 415.2356
# <class 'str'>

# %%
Vrushabh = 12
print(type(Vrushabh))
# Out:
# <class 'int'>

# %%
Data = 2.0
print(type(Data))
# Out:
# <class 'float'>

# %%
Vrushabh = True
print(type(Vrushabh))
# Out:
# <class 'bool'>

# %% [markdown]
# # 2. Explicit Type Conversion in Python -
#
# # In this method, Python needs user involvement to convert the variable data type into the required data type.
#
# Mainly type casting can be done with these data type functions -
#
# 1. Int() - Python int() function take float or string as an argument and returns int type object.
#
# 2. float() - Python float() function take int or string as an argument and return float type object.
#
# 3. str() -  Python str() function takes float or int as an argument and returns string type object.

# %%
Vrushabh = int(input())
print(Vrushabh)
# Out:
# kasliwal
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-03a497dfc78e> in <cell line: 1>()
# ----> 1 Vrushabh = int(input())
#       2 print(Vrushabh)
#
# ValueError: invalid literal for int() with base 10: 'kasliwal'

# %%
Data = float(input())
print(Data)
# Out:
# 15
# 15.0

# %%
Vrushabh = "10"
print(int(Vrushabh))
# Out:
# 10

# %%
Data = "xyz"
print(int(Data))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-79112ed236e3> in <cell line: 2>()
#       1 Data = "xyz"
# ----> 2 print(int(Data))
#
# ValueError: invalid literal for int() with base 10: 'xyz'

# %%
Vrushabh = "10"
print(float(Vrushabh))
# Out:
# 10.0

# %%
Data = 8.87
Science = int(Data) + 1
print(Science)
# Out:
# 9

# %%
Vrushabh = 8
Kasliwal = str(Vrushabh) + 1
print(Kasliwal)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-327a22d61b06> in <cell line: 2>()
#       1 Vrushabh = 8
# ----> 2 Kasliwal = str(Vrushabh) + 1
#       3 print(Kasliwal)
#
# TypeError: can only concatenate str (not "int") to str

# %%
Vrushabh = int(input("Enter a integer number - "))
print("Your entered number -",Vrushabh)
# Out:
# Enter a integer number - 10
# Your entered number - 10

# %%
print(164659569569596859658968596859685)
# Out:
# 164659569569596859658968596859685

# %%
print(2.12345554784598996569)
# Out:
# 2.1234555478459898

# %%
print("@#$%^&*())!@#$$%%%^^^_ _ _ _ _ _")
# Out:
# @#$%^&*())!@#$$%%%^^^_ _ _ _ _ _

# %% [markdown]
# # How to check type of data types ??

# %%
print(type(5))
# Out:
# <class 'int'>

# %%
print(type(2.12))
# Out:
# <class 'float'>

# %%
# Type is not defined in proper way

print(Type(False))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-0a22562f82da> in <cell line: 2>()
#       1 # Type is not defined in proper way
# ----> 2 print(Type(False))
#
# NameError: name 'Type' is not defined

# %%
print(type(False))
# Out:
# <class 'bool'>

# %%
# True is not written in proper way

print(type(true))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-8b79776fa1f5> in <cell line: 2>()
#       1 # True is not written in proper way
# ----> 2 print(type(true))
#
# NameError: name 'true' is not defined

# %%
print(type(True))

# %%
print(type("True"))
# Out:
# <class 'str'>

# %%
# print does not store anything, it only show the output on the screen

type(print("abcdefgh"))
# Out:
# abcdefgh
# NoneType

# %% [markdown]
# # Use of sep and end -

# %%
print(4,5,6,7,"bce",sep="+")
# Out:
# 4+5+6+7+bce

# %%
print("Hello",end="join")
print("Vrushabh Kasliwal")
# Out:
# HellojoinVrushabh Kasliwal

# %%
print(1,2,3,4,5,sep="\n")
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
print("Python","Sql","Numpy","Pandas",sep = "Science",end = "t")
print("\nVrushabh")
# Out:
# PythonScienceSqlScienceNumpySciencePandast
# Vrushabh

# %%
print("Python","Sql","Numpy","Pandas",sep = "Science",end = "t\n")
print("Vrushabh")
# Out:
# PythonScienceSqlScienceNumpySciencePandast
# Vrushabh

# %%
print("Python","Sql","Numpy","Pandas",sep = "Science",end = "t/n")
print("Vrushabh")
# Out:
# PythonScienceSqlScienceNumpySciencePandast/nVrushabh

# %%
# Tricky code

print("*****\t*",end ="vrushabh")
print("something",sep ="+")
print("hello data scientist",sep =" ++++ ")
# Out:
# *****	*vrushabhsomething
# hello data scientist

# %%
# Tricky code

print("*****\t*",end ="data")
print("something",sep ="+")
print("hello","data","scientist",sep =" ++++ ")
# Out:
# *****	*datasomething
# hello ++++ data ++++ scientist

# %%
# Tricky code

print("*****\t*",end ="data")
print("something",sep ="+")
print("hello","data","scientist",end =" ++++ ")
# Out:
# *****	*datasomething
# hello data scientist ++++

# %%
# Concatented string

num1 = input()
num2 = input()
print(num1 + num2)
# Out:
# 10
# 20
# 1020

# %%
num1 = int(input("Enter a integer value - "))
num2 = int(input("Enter a integer value - "))
sum = num1 + num2
print("SUM IS -",sum)
# Out:
# Enter a integer value - 10
# Enter a integer value - 15
# SUM IS - 25

# %%
# Expoential Value

num1 = int(input("enter a value - "))
num2 = int(input("enter a value - "))
print(num1 ** num2)
# Out:
# enter a value - 10
# enter a value - 3
# 1000

# %% [markdown]
# # Intresting Concepts

# %%
Val = -8.123
print(int(Val))
# Out:
# -8

# %%
Num = 5.0
print(int(Num))
# Out:
# 5

# %%
Data = "5"
print(int(Data))
# Out:
# 5

# %%
Value = "5.0"
print(int(Value))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-1560d000e6cb> in <cell line: 2>()
#       1 Value = "5.0"
# ----> 2 print(int(Value))
#
# ValueError: invalid literal for int() with base 10: '5.0'

# %%
# How to solve above code error

Value = "5.0"
print(int(float(Value)))
# Out:
# 5

# %% [markdown]
# # Assignment Problems

# %%
'''

Example Input -
Ram

Example Output -
Hello Ram

'''
name = input()
print("Hello",name)
# Out:
# Ram
# Hello Ram

# %%
'''

Your friend Rahul plans to visit exotic countries all around the world.
Sadly, Rahul's math skills aren't good enough.
Given the amount of money Rahul has before the currency exchange and the amount of money that is spent from his savings,
print the amount of money that remains in his savings.

Input -
116
12

Output -
104

'''
Amount_of_money_spent = int(input())
Exchanging_amount = int(input())
Amount_of_money_that_left = Amount_of_money_spent - Exchanging_amount
print(Amount_of_money_that_left)
# Out:
# 116
# 12
# 104

# %%
'''

Problem Description
Given two numbers A and B. Concatenate the two numbers and print it.


Input Format -
There are two input lines
The first line has a single integer A.
The second line has a single integer B.


Output Format -
Print in a single line the concatenated number.


Example Input -
Input 1 -
4
5
Input 2 -
16
2


Example Output -
Output 1 -
45
Output 2 -
162


Example Explanation -
Explanation 1 -
Concatenation of 4 and 5 is 45.
Explanation 2 -
Concatenation of 16 and 2 is 162.

'''
# 1 way

Num_1 = input()
Num_2 = input()
print(Num_1 + Num_2)
print("-------")

# 2 way

Num_1 = int(input())
Num_2 = int(input())
# Typecasting of two input numbers
Num_3 = str(Num_1)
Num_4 = str(Num_2)
print(Num_3 + Num_4)
# Out:
# 4
# 5
# 45
# -------
# 4
# 5
# 45

# %%
'''

Print the first five letters of the English alphabet i.e. A, B, C, D and E.

Output -
A
B
C
D
E

'''
# 1 way

print("A","B","C","D","E",sep="\n")
print("-------")
# 2 way

print("A\nB\nC\nD\nE")
# Out:
# A
# B
# C
# D
# E
# -------
# A
# B
# C
# D
# E

# %%
'''

Given two names A and B as input, print "A says Hi to B" (Without quotations), where A and B are the names in input.

Output:-
Ram says Hi to Shyam

'''

Input_1 = input()
Input_2 = input()
print(Input_1,"says Hi to",Input_2)
# Out:
# Ram
# Shyam
# Ram says Hi to Shyam

# %% [markdown]
# # Additional Problems

# %%
'''

You're going to write some code to help you cook a gorgeous lasagna from your favorite cookbook.
According to your cookbook, the Lasagna should be in the oven for 40 minutes. Given the time (in minutes), the lasagna has been in the oven,
find how many more minutes the lasagna still needs to bake for.

Input -
30

Output -
10

'''

Time_Minutes = int(input())
Lasagna_in_the_oven = 40
print(Lasagna_in_the_oven - Time_Minutes)
# Out:
# 30
# 10

# %%
'''

You'll write some code to help you cook a gorgeous lasagna from your favorite cookbook.
Now, you also want to add a few layers to the lasagna. Assume **each layer takes 2 minutes** to prepare.
Given the number of layers you want to add to the lasagna, find how many minutes you would spend making them.

Example Input
Input -
2

Example Output
Output -
4

'''

Number_of_layers_you_want_to_add_to_the_lasagna = int(input())
Each_layers_takes = 2
How_many_minutes_spend_to_baking = Number_of_layers_you_want_to_add_to_the_lasagna * Each_layers_takes
print(How_many_minutes_spend_to_baking)
# Out:
# 2
# 4

# %%
'''

Problem Description
You wrote some code to help you cook a gorgeous lasagna from your favorite cookbook.
Now, you want to find the total number of minutes you've been cooking
for the sum of your preparation time and the time the lasagna has already spent baking in the oven.
The preparation time of one layer is 2 minutes.
Given the number of layers added to the lasagna and the number of minutes the lasagna has been baking in the oven,
find the total elapsed cooking time (prep + bake) in minutes.

Example Input -
Input 1 -
3
20

Input 2 -
1
29


Example Output -
Output 1 -
26

Output 2 -
31

'''

Number_of_layers_added_to_the_lasagna = int(input())
Number_of_minutes_the_lasagna = int(input())
Preparation_time_of_one_layer = 2
Total_elapsed_cooking_time = (( Preparation_time_of_one_layer * Number_of_layers_added_to_the_lasagna ) + Number_of_minutes_the_lasagna)
print(Total_elapsed_cooking_time)
# Out:
# 3
# 20
# 26

# %%
'''

Given the value of a single bill and the number of bills you received, print the total value of the bills.

Note: The value of all the bills are same

Input -
12
10

Output -
120

'''

Value_of_single_bill = int(input())
Number_of_bills = int(input())
Total_value_of_bills = Value_of_single_bill * Number_of_bills
print(Total_value_of_bills)
# Out:
# 12
# 10
# 120

# %%
'''

Problem Description

Your friend Rahul plans to visit exotic countries all around the world. Sadly, Rahul's math skills aren't good enough. Take the amount of money Rahul has before the currency exchange and the amount of money that is spent from his savings as input, print the amount of money that remains in his savings.

Input Format -
The first line contains an integer N denoting the total savings, the amount of money before exchange.
The second line contains an integer M denoting the exchanging amount, denoting the amount of money that is spent from the savings.

Output Format -
Print a single line denoting the amount of money that is left in his savings.

Problem Constraints -
1 <= N <= 1000
1 <= M <= N

Example Input
Input -
116
12

Example Output
Output -
104

'''

Amount_of_money_spent = int(input())
Exchanging_amount = int(input())
Amount_of_money_that_left = Amount_of_money_spent - Exchanging_amount
print(Amount_of_money_that_left)
# Out:
# 116
# 12
# 104

# %% [markdown]
# # Extra Problems

# %%
# Take 5 subject marks from user and display average

m_math = 68
m_eng = 75
m_phy = 85
m_chem = 95
m_bio = 80

TOTAL = m_math + m_eng + m_phy + m_chem + m_bio

P = (TOTAL / 500) * 100

T1 = "Your percentage is"
T2 = "%"

print(T1,int(P),T2)
print()
print(T1,round(P,1),T2)
# Out:
# Your percentage is 80 %
#
# Your percentage is 80.6 %

# %%
# How to find quotient and remainder of number

Num_1 = 14
Num_2 = 7
print(Num_1 / Num_2)
print("Quotient = ", Num_1 // Num_2)
print("Remainder = ", Num_1 % Num_2)
# Out:
# 2.0
# Quotient =  2
# Remainder =  0
